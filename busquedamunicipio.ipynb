# %%
# Create code to answer each of the following questions.
# Hint: You will need multiple target URLs and multiple API requests.

# Dependencies
import requests
import json
import pandas as pd

# Google API Key
from config import gkey

# %%
#busqueda de la lat y long de los municipios
concatenadomunicipio = "Álvaro Obregón , Ciudad de México"

params = {
    "address": concatenadomunicipio,
    "key": gkey
}

base_url = "https://maps.googleapis.com/maps/api/geocode/json"

print("lat y long del municipio")

my_geo = requests.get(base_url, params).json()

lat = my_geo["results"][0]["geometry"]["location"]["lat"]
lng = my_geo["results"][0]["geometry"]["location"]["lng"]

print({lat},{lng})
# Out:
# lat y long del municipio
# {19.3605334} {-99.2267067}

# %%
#busqueda de los dentistas
basedentista = pd.DataFrame (columns = ['DENTIST Name','DENTIST Address','LAT','LONG','ESTADO'])
target_type = "dentist"
radius = 10000

# rewrite params dict

params = {
    "location": f"{lat},{lng}",
    "types": target_type,
    "radius": radius,
    "key": gkey
}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

print("dentist")

# Run request
response = requests.get(base_url, params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)

busquedadentista = response.json()

# Print the JSON (pretty printed)
#print(json.dumps(seattle_bikes, indent=4, sort_keys=True))

a=0
for place in busquedadentista["results"]:
    basedentista.loc[a,"DENTIST Name"] = busquedadentista["results"][a]["name"]
    basedentista.loc[a,"DENTIST Address"] = busquedadentista["results"][a]["vicinity"]
    basedentista.loc[a,"DENTIST Address"] = busquedadentista["results"][a]["vicinity"]
    basedentista.loc[a,"LAT"] = busquedadentista["results"][a]["geometry"]["location"]["lat"]
    basedentista.loc[a,"LONG"] = busquedadentista["results"][a]["geometry"]["location"]["lng"]
    basedentista.loc[a,"ESTADO"] = busquedadentista["results"][a]["plus_code"]["compound_code"]
    a=a+1



#print(busquedadentista["results"][0]["name"])
#print(busquedadentista["results"][0]["vicinity"])
basedentista
# Out:
# dentist
#                                          DENTIST Name  \
# 0                              Clínica Dental Privada
# 1                           My Dentists Dental Clinic
# 2                   Sonría - Clínicas Dentales - Roma
# 3                 Doctor Luis Guillén Gil y Asociados
# 4                      Dr. Miguel Angel Ramos Alvarez
# 5                               Clinica Dental Orthos
# 6                                AUREA -Smile Design-
# 7                         Dr. Hector Rincón Rodriguez
# 8       Del Rey Dental - Periodoncia e Implantes CDMX
# 9   ORTHOMAX, Ortodoncia y Cirugía Maxilofacial, E...
# 10                             Clinica Dental Polanco
# 11                                 dentalia Altavista
# 12                               Cirugía Maxilofacial
# 13                                           Dentalia
# 14                                     Clínica Dental
# 15                   Doctor Manuel Farill y Asociados
# 16                                           Dentista
# 17                      Compañía Dental Internacional
# 18                       Clinica y Laboratorio Dental
# 19                         Smile Design Center México
#
#                                       DENTIST Address      LAT     LONG  \
# 0                     Holbein 217 1104, Benito Juarez  19.3812   -99.18
# 1    Avenida Coyoacán 1878, Acacias, Ciudad de México  19.3617  -99.172
# 2              Tonalá 6, Roma Norte, Ciudad de México  19.4215 -99.1634
# 3          Avenida Universidad 1003, Ciudad de México  19.3673 -99.1673
# 4   Amores 942, Colonia del Valle Centro, Benito J...  19.3834 -99.1661
# 5   Oso 127-interior 403, Colonia del Valle Sur, C...  19.3728 -99.1782
# 6                Tepic 91, Roma Sur, Ciudad de México  19.4068 -99.1648
# 7   Amores 942, Colonia del Valle Centro, Benito J...  19.3833 -99.1662
# 8   Pilares 108-Int.102, Colonia del Valle Centro,...   19.379 -99.1705
# 9   Avenida Universidad 1134, Xoco, Col Xoco, Dele...  19.3635 -99.1693
# 10     Hegel 209, Polanco V Sección, Ciudad de México  19.4351 -99.1882
# 11  Plaza Altavista Calzada, Desierto de los Leone...  19.3489 -99.1893
# 12                Tlaxcala 177, Hipódromo, Cuauhtémoc  19.4069   -99.17
# 13  Boulevard Magnocentro 26, La Herradura, Naucal...  19.4058 -99.2726
# 14             Cerrada Felix Cuevas 38, Benito Juarez  19.3744  -99.176
# 15  Melchor Ocampo 19-103, Tizapán San Ángel, Ciud...  19.3361  -99.202
# 16  Vasco de Quiroga 1726, Santa Fé, Ciudad de México  19.3808 -99.2417
# 17  Odontología 74, Copilco Universidad, Ciudad de...  19.3355 -99.1809
# 18  Avenida Copilco 225, Copilco Universidad, Ciud...  19.3366 -99.1821
# 19  Calle Heroes de Padierna 132-55, San Jerónimo ...  19.3232 -99.2229
#
#                                                ESTADO
# 0                   9RJ9+FX Mexico City, CDMX, Mexico
# 1                   9R6H+M6 Mexico City, CDMX, Mexico
# 2                   CRCP+HJ Mexico City, CDMX, Mexico
# 3                   9R8M+W3 Mexico City, CDMX, Mexico
# 4   9RMM+9G Colonia del Valle Centro, Ciudad de Mé...
# 5                   9RFC+4P Mexico City, CDMX, Mexico
# 6                   CR4P+P3 Mexico City, CDMX, Mexico
# 7   9RMM+8G Colonia del Valle Centro, Ciudad de Mé...
# 8                   9RHH+JQ Mexico City, CDMX, Mexico
# 9             9R7J+97 Xoco, Mexico City, CDMX, Mexico
# 10                  CRP6+2P Mexico City, CDMX, Mexico
# 11                  8RX6+H7 Mexico City, CDMX, Mexico
# 12  CR4J+Q2 Hipódromo, Ciudad de México, CDMX, Mexico
# 13  CP4G+8X Naucalpan de Juárez, State of Mexico, ...
# 14                  9RFF+QH Mexico City, CDMX, Mexico
# 15                  8QPX+C6 Mexico City, CDMX, Mexico
# 16                  9QJ5+88 Mexico City, CDMX, Mexico
# 17                  8RP9+6J Mexico City, CDMX, Mexico
# 18                  8RP9+J4 Mexico City, CDMX, Mexico
# 19                  8QFG+7R Mexico City, CDMX, Mexico
