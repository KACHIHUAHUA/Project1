# %%
# Import Dependencies
import gmaps
import requests
import json
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Google API Key
from config import gkey
gmaps.configure(api_key=gkey)

# %%
#load Data from csv file
file_to_load = "estadosfronterisos.csv"
denue_data = pd.read_csv(file_to_load, encoding = "ISO-8859-1")
denue_data.head(10)
# Out:
#              ï»¿nom_estab  codigo_act  \
# 0           0PTIDENTBELLA      621211
# 1  6TA & E 6TA & E DENTAL      621211
# 2          6TA & E DENTAL      621211
# 3        7 CLINICA DENTAL      621211
# 4             ABBA DENTAL      621211
# 5              ABC DENTAL      621211
# 6            ADAME DENTAL      621211
# 7     ADVANCE DENTAL CARE      621211
# 8  ADVANCED DENTAL CLINIC      621211
# 9  ADVANCED DENTAL CLINIC      621211
#
#                                  nombre_act          per_ocu  cod_postal  \
# 0  Consultorios dentales del sector privado   0 a 5 personas     21100.0
# 1  Consultorios dentales del sector privado   0 a 5 personas     22000.0
# 2  Consultorios dentales del sector privado   0 a 5 personas     22000.0
# 3  Consultorios dentales del sector privado   0 a 5 personas     22000.0
# 4  Consultorios dentales del sector privado   0 a 5 personas     21970.0
# 5  Consultorios dentales del sector privado   0 a 5 personas     22010.0
# 6  Consultorios dentales del sector privado  6 a 10 personas     21400.0
# 7  Consultorios dentales del sector privado   0 a 5 personas     21970.0
# 8  Consultorios dentales del sector privado   0 a 5 personas     22010.0
# 9  Consultorios dentales del sector privado   0 a 5 personas     22010.0
#
#    cve_ent          entidad  cve_mun municipio  cve_loc  \
# 0        2  BAJA CALIFORNIA        2  Mexicali        1
# 1        2  BAJA CALIFORNIA        4   Tijuana        1
# 2        2  BAJA CALIFORNIA        4   Tijuana        1
# 3        2  BAJA CALIFORNIA        4   Tijuana        1
# 4        2  BAJA CALIFORNIA        2  Mexicali      111
# 5        2  BAJA CALIFORNIA        4   Tijuana        1
# 6        2  BAJA CALIFORNIA        3    Tecate        1
# 7        2  BAJA CALIFORNIA        2  Mexicali      111
# 8        2  BAJA CALIFORNIA        4   Tijuana        1
# 9        2  BAJA CALIFORNIA        4   Tijuana        1
#
#                       localidad    latitud    longitud fecha_alta
# 0                      Mexicali  32.663072 -115.488942    2010-07
# 1                       Tijuana  32.525102 -117.029433    2010-07
# 2                       Tijuana  32.525102 -117.029433    2019-11
# 3                       Tijuana  32.529883 -117.033555    2019-11
# 4  Vicente Guerrero (Algodones)  32.716927 -114.732017    2014-12
# 5                       Tijuana  32.540496 -117.031007    2019-11
# 6                        Tecate  32.576198 -116.626361    2010-07
# 7  Vicente Guerrero (Algodones)  32.715890 -114.730073    2019-11
# 8                       Tijuana  32.524917 -117.020137    2019-11
# 9                       Tijuana  32.524917 -117.020137    2019-11

# %%
# Customize the size of the figure
## Assign the marker layer to a variable
coordinates =denue_data[['latitud', "longitud"]]
figure_layout = {   
    'height': '450px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig2 = gmaps.figure(layout=figure_layout)
#Assign the marker layer to a variable
markers = gmaps.marker_layer(coordinates)
#Add the layer to the map
fig2.add_layer(markers)
fig2
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='450px', margin='0 auto 0 auto', padding='1px'))
