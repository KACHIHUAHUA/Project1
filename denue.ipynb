# %%
import pandas as pd
import os
import numpy as np

# %%
file_to_load = "denue-filtrado.csv"
denue_data = pd.read_csv(file_to_load, encoding = "ISO-8859-1")
denue_data.head()
# Out:
#                                            nom_estab  codigo_act  \
# 0               (H) CONSULTORIO AGUASCALIENTES, AGS.      621111
# 1            176 SUCURSAL  EMILIANO ZAPATA SIGLO XXI      621511
# 2  184  SUCURSAL CONVENCIÓN ORIENTE  GRUPO DIAGNÓ...      621511
# 3                                AA GRUPO CHICAGO 85      624191
# 4                                AA GRUPO LA SOLEDAD      624191
#
#                                           nombre_act           per_ocu  \
# 0  Consultorios de medicina general del sector pr...    0 a 5 personas
# 1  Laboratorios médicos y de diagnóstico del sect...  31 a 50 personas
# 2  Laboratorios médicos y de diagnóstico del sect...    0 a 5 personas
# 3  Agrupaciones de autoayuda para alcohólicos y p...  11 a 30 personas
# 4  Agrupaciones de autoayuda para alcohólicos y p...    0 a 5 personas
#
#    cod_postal  cve_ent         entidad  cve_mun       municipio  cve_loc  \
# ...

# %%
filter_denue = denue_data.loc[denue_data["codigo_act"] == 621211, :]
filter_denue
# Out:
#                                   nom_estab  codigo_act  \
# 9                   AD ODONTOLOGIA AVANZADA      621211
# 63                              ALFA DENTAL      621211
# 70                     ALORA +DENT DENTISTA      621211
# 73                               AMG DENTAL      621211
# 86                        ARA-DENTAL CLINIC      621211
# ...                                     ...         ...
# 235523  VILLA VERDE ESPECIALIDADES DENTALES      621211
# 235524                            VITA DENT      621211
# 235525                   VITALDENT SAN JOSE      621211
# 235526                            VOCA SANA      621211
# 235535        ZES DENTAL CONSULTORIO DENTAL      621211
#
#                                       nombre_act         per_ocu  cod_postal  \
# 9       Consultorios dentales del sector privado  0 a 5 personas     20127.0
# 63      Consultorios dentales del sector privado  0 a 5 personas     20400.0
# ...
