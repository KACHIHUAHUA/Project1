# %%
# Create code to answer each of the following questions.
# Hint: You will need multiple target URLs and multiple API requests.

# Dependencies
import requests
import json
import pandas as pd

# Google API Key
from config import gkey

# %%
#busqueda de la lat y long de los municipios
LISTAESTADOS=["36970,36973,36974,36975,36976,36977,36980,36983,36984,36985,36986,36987]
concatenadocp = "36970

params = {
    "address": concatenadocp,
    "key": gkey
}

base_url = "https://maps.googleapis.com/maps/api/geocode/json"

print("lat y long del municipio")

my_geo = requests.get(base_url, params).json()

lat = my_geo["results"][0]["geometry"]["location"]["lat"]
lng = my_geo["results"][0]["geometry"]["location"]["lng"]

print({lat},{lng})
# Out:
# lat y long del municipio
# {19.4002495} {-99.17744619999999}

# %%
#busqueda de los dentistas
basedentista = pd.DataFrame (columns = ['DENTIST Name','DENTIST Address','LAT','LONG','ESTADO'])
target_type = "dentist"
radius = 10000

# rewrite params dict

params = {
    "location": f"{lat},{lng}",
    "types": target_type,
    "radius": radius,
    "key": gkey
}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

print("dentist")

# Run request
response = requests.get(base_url, params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)

busquedadentista = response.json()

# Print the JSON (pretty printed)
#print(json.dumps(seattle_bikes, indent=4, sort_keys=True))

a=0
for place in busquedadentista["results"]:
    basedentista.loc[a,"DENTIST Name"] = busquedadentista["results"][a]["name"]
    basedentista.loc[a,"DENTIST Address"] = busquedadentista["results"][a]["vicinity"]
    basedentista.loc[a,"DENTIST Address"] = busquedadentista["results"][a]["vicinity"]
    basedentista.loc[a,"LAT"] = busquedadentista["results"][a]["geometry"]["location"]["lat"]
    basedentista.loc[a,"LONG"] = busquedadentista["results"][a]["geometry"]["location"]["lng"]
    basedentista.loc[a,"ESTADO"] = busquedadentista["results"][a]["plus_code"]["compound_code"]
    a=a+1



#print(busquedadentista["results"][0]["name"])
#print(busquedadentista["results"][0]["vicinity"])
basedentista
# Out:
# dentist
#                                          DENTIST Name  \
# 0   UNITEC Marina - Universidad Tecnológica de México
# 1              Doctor González A.C.osta Marco Antonio
# 2                   Sonría - Clínicas Dentales - Roma
# 3                              Clínica Dental Privada
# 4                              Clinica Dental Polanco
# 5                                AUREA -Smile Design-
# 6                           My Dentists Dental Clinic
# 7                      Dr. Miguel Angel Ramos Alvarez
# 8                 Doctor Luis Guillén Gil y Asociados
# 9                               Clinica Dental Orthos
# 10                        Dr. Hector Rincón Rodriguez
# 11                               Cirugía Maxilofacial
# 12                                           dentalia
# 13      Del Rey Dental - Periodoncia e Implantes CDMX
# 14  ORTHOMAX, Ortodoncia y Cirugía Maxilofacial, E...
# 15                          dentalia Pabellón Polanco
# 16                                 dentalia Altavista
# 17                                     Clínica Dental
# 18                              Cortez Perez Oscar Dr
# 19                              Clinica Dental MarYet
#
#                                       DENTIST Address      LAT     LONG  \
# 0   Avenida Marina Nacional 162, Anáhuac I Sección...  19.4479 -99.1808
# 1   Calle Tomas Alva Edison 149, San Rafael, Ciuda...  19.4386 -99.1571
# 2              Tonalá 6, Roma Norte, Ciudad de México  19.4215 -99.1634
# 3                     Holbein 217 1104, Benito Juarez  19.3812   -99.18
# 4      Hegel 209, Polanco V Sección, Ciudad de México  19.4351 -99.1882
# 5                Tepic 91, Roma Sur, Ciudad de México  19.4068 -99.1648
# 6    Avenida Coyoacán 1878, Acacias, Ciudad de México  19.3617  -99.172
# 7   Amores 942, Colonia del Valle Centro, Benito J...  19.3834 -99.1661
# 8          Avenida Universidad 1003, Ciudad de México  19.3673 -99.1673
# 9   Oso 127-interior 403, Colonia del Valle Sur, C...  19.3728 -99.1782
# 10  Amores 942, Colonia del Valle Centro, Benito J...  19.3833 -99.1662
# 11                Tlaxcala 177, Hipódromo, Cuauhtémoc  19.4069   -99.17
# 12  Avenida Paseo de la Reforma 222, Juárez, Ciuda...  19.4287 -99.1617
# 13  Pilares 108-Int.102, Colonia del Valle Centro,...   19.379 -99.1705
# 14  Avenida Universidad 1134, Xoco, Col Xoco, Dele...  19.3635 -99.1693
# 15  Avenida Ejército Nacional 980, Polanco I Secci...  19.4378 -99.2068
# 16  Plaza Altavista Calzada, Desierto de los Leone...  19.3489 -99.1893
# 17             Cerrada Felix Cuevas 38, Benito Juarez  19.3744  -99.176
# 18  Avenida Baja California 210-102, Roma Sur, Ciu...  19.4058 -99.1668
# 19  Avenida Marina Nacional 286, Anáhuac I Sección...  19.4411 -99.1762
#
#                                                ESTADO
# 0                   CRX9+5M Mexico City, CDMX, Mexico
# 1                   CRQV+C4 Mexico City, CDMX, Mexico
# 2                   CRCP+HJ Mexico City, CDMX, Mexico
# 3                   9RJ9+FX Mexico City, CDMX, Mexico
# 4                   CRP6+2P Mexico City, CDMX, Mexico
# 5                   CR4P+P3 Mexico City, CDMX, Mexico
# 6                   9R6H+M6 Mexico City, CDMX, Mexico
# 7   9RMM+9G Colonia del Valle Centro, Ciudad de Mé...
# 8                   9R8M+W3 Mexico City, CDMX, Mexico
# 9                   9RFC+4P Mexico City, CDMX, Mexico
# 10  9RMM+8G Colonia del Valle Centro, Ciudad de Mé...
# 11  CR4J+Q2 Hipódromo, Ciudad de México, CDMX, Mexico
# 12                  CRHQ+F8 Mexico City, CDMX, Mexico
# 13                  9RHH+JQ Mexico City, CDMX, Mexico
# 14            9R7J+97 Xoco, Mexico City, CDMX, Mexico
# 15                  CQQV+47 Mexico City, CDMX, Mexico
# 16                  8RX6+H7 Mexico City, CDMX, Mexico
# 17                  9RFF+QH Mexico City, CDMX, Mexico
# 18                  CR4M+87 Mexico City, CDMX, Mexico
# 19                  CRRF+CG Mexico City, CDMX, Mexico
